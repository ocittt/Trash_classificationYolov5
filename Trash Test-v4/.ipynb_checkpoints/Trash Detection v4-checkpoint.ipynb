# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !pip3 install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cu111
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.8.2+cu111

# %%
# !pip install opencv-python
# Out:
# ^C

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !pip install tensorboard

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\lepas/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-10-6 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
img = 'https://static01.nyt.com/images/2010/10/10/us/10google2/10google2-jumbo.jpg?quality=75&auto=webp'

# %%
# %matplotlib inline

# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 681x1024 1 person, 13 cars, 5 trucks
# Speed: 557.6ms pre-process, 1405.8ms inference, 11.9ms NMS per image at shape (1, 3, 448, 640)

# %%
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('data','images')
labels = ['glass', 'metal','plastic']
number_imgs = 150

# %%
# !git clone https://github.com/heartexlabs/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 640 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 1
# Out:
# INTEL MKL ERROR: The paging file is too small for this operation to complete. mkl_intel_thread.1.dll.INTEL MKL ERROR: The paging file is too small for this operation to complete. mkl_intel_thread.1.dll.INTEL MKL ERROR: The paging file is too small for this operation to complete. mkl_intel_thread.1.dll.
#
#
# Intel MKL FATAL ERROR: Cannot load mkl_intel_thread.1.dll.
# Intel MKL FATAL ERROR: Cannot load mkl_intel_thread.1.dll.Intel MKL FATAL ERROR: Cannot load mkl_intel_thread.1.dll.
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom', path='yolov5/runs/train/exp5/weights/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\lepas/.cache\torch\hub\master.zip
# YOLOv5  2022-10-6 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data','images','glass6.jpg.')

# %%
img = 'https://sc04.alicdn.com/kf/Hc90c15b9545e4933ae3634220953143ah.jpg'

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 750x750 1 metal
# Speed: 80.5ms pre-process, 78.0ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cap = cv2.VideoCapture('trash.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
