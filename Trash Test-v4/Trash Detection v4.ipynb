# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !pip3 install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cu111
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.8.2+cu111

# %%
# !pip install opencv-python
# Out:
# ^C

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !pip install tensorboard

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Lenovo/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-12-29 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce MX230, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
img = 'https://static01.nyt.com/images/2010/10/10/us/10google2/10google2-jumbo.jpg?quality=75&auto=webp'

# %%
# %matplotlib inline

# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 681x1024 1 person, 13 cars, 5 trucks
# Speed: 557.6ms pre-process, 1405.8ms inference, 11.9ms NMS per image at shape (1, 3, 448, 640)

# %%
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('data','images')
labels = ['glass', 'metal','plastic']
number_imgs = 150

# %%
# !git clone https://github.com/heartexlabs/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 640 --batch 20 --epochs 300 --data dataset.yaml --weights yolov5s.pt --workers 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=300, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=1, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 136 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to 'C:\Users\lepas\Documents\Trash': No such file or directory
# YOLOv5  2022-10-5 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom', path='yolov5/runs/train/exp16/weights/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Lenovo/.cache\torch\hub\master.zip
# YOLOv5  2022-12-31 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce MX230, 2048MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data','images','glass6.jpg.')

# %%
img = 'trash.mp4'

# %%
results = model(img)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 results = model(img)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# File ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.__class__():
# ---> 27         return func(*args, **kwargs)
#
# ...

# %%
results.print()

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show

# %%
cap = cv2.VideoCapture('testdata.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Input In [11]
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...
